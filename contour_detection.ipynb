# %%
import cv2
import os
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
fx = [[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]]
fy = [[-1, -2, -1], [0, 0, 0], [1, 2, 1]]

# %%
img = cv2.imread("camera.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')

# %%
(x_size, y_size) = img.shape

# %%
X = np.zeros((x_size-2, y_size-2), dtype=int)
Y = np.zeros((x_size-2, y_size-2), dtype=int)
F = np.zeros((x_size-2, y_size-2), dtype=int)

# %%
for x in range(0, x_size-2):
    for y in range(0, y_size-2):
        X[x] = img[x][y] * fx[0][0] + img[x][y+1] * fx[0][1] + img[x][y+2] * fx[0][2] + img[x+1][y] * fx[1][0] + img[x+1][y+1] * fx[1][1] + img[x+1][y+2] * fx[1][2] + img[x+2][y] * fx[2][0] + img[x+2][y+1] * fx[2][1] + img[x+2][y+2] * fx[2][2]

for y in range(0, y_size-2):
    for x in range(0, x_size-2):
        Y[x][y] = img[x][y] * fx[0][0] + img[x][y+1] * fx[0][1] + img[x][y+2] * fx[0][2] + img[x+1][y] * fx[1][0] + img[x+1][y+1] * fx[1][1] + img[x+1][y+2] * fx[1][2] + img[x+2][y] * fx[2][0] + img[x+2][y+1] * fx[2][1] + img[x+2][y+2] * fx[2][2]

for y in range(0, y_size-2):
    for x in range(0, x_size-2):
        F[x][y] = math.sqrt(X[x][y] ** 2 + Y[x][y] ** 2)

# %%
plt.imshow(F, cmap='gray')
